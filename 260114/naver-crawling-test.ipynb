# %%
# 셀(*주석처리) > 실제 파이썬 코드 실행되는 공간/단위
# [*] : 셀 작동중인지의 여부 > [숫자] : 작동 완료
# Kernel : 가상환경
# 파이썬은 초심자 프로그래밍 언어 > 자동화 프로그램 구현 > 무수히 많은 라이브러리 모듈 생성
# 어떤 라이브러리 모듈 : 3.
# 어떤 라이브러리 모듈 : 2.
# 1개 프로젝트의 > 셀이 많다면 과부화 옴 > restart 해야함

# %% [markdown]
# # 파이썬 기초 문법
# ＊변수

# %%
# 네이버 웹포털 사이트 내 뉴스 카테고리에서 특정 키워드 크롤링 해오기
# 크롤링 : 외부에서 데이터를 수집해오는 행위
# ctrl + / : 주석처리 가능, ctrl + z : 직전 단계로 돌아가기 

import requests
from bs4 import BeautifulSoup

query = "마케팅" # 변수 선언 후 값을 할당
url = f"https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query={query}" # f-string 문법

headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36"
}

response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")
titles = soup.select("a.fender-ui_228e3bd1.MNH2zYqVX0VCatL92VdS")

for i, title in enumerate(titles) : 
    print(f"{i + 1}. {title.text}")
    
# bs4.BeautifulSoup()
# print(response) #print 함수 > 어떤 기능을 구현하고자 할 때
# 방법은 여러가지
    
# 기초의 소중함
# 학습 : 기초지식 + 생성형 AI > 더 많은 구현 가능
# 응용 & 문제 해결 능력
# 변수, 문자열 자료형, 디셔너리 자료구조, 리스트 자료구조, 반복문, enum타입, 인덱스, 슬라이싱 기능 출력?
# Out:
# 1. 이찬진 "막연한 기대감에 달러상품 판매 증가…마케팅 자제"
# 2. [테크스냅] KT 대학생 마케팅 서포터즈 'Y퓨처리스트' 모집
# 3. KT, 25일까지 대학생 마케팅 서포터즈 모집
# 4. 영업 환경 악화에 손잡은 제약사들…공동 마케팅 전략 본격화
# 5. 기아, 호주오픈 파트너십 25주년 기념 캠패인…EV 마케팅 속도
# 6. 기아, 2026 호주오픈서 전기차 42% 도입 과감한 마케팅
# 7. 동해시, ‘스포츠 마케팅’ 통했다… 지역경제 329억 원 활력
# 8. KT, 대학생 마케팅 서포터즈 'Y퓨처리스트 24기' 모집
# 9. KT, 대학생 마케팅 서포터즈 'Y퓨처리스트' 24기 모집
# 10. 1020 겨냥한 갤럭시 마케팅... 삼성전자, '갤럭시 크루 2026' 출범
