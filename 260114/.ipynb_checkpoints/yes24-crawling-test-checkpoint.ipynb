# %%
# pseudo code : 가짜의 코드 = 거짓의 코드
# 만약 내가 yes24 크롤링 한다면?!
# 1) 수집하고자하는 사이트의 주소를 확인
# 2) 해당 사이트에서 책제목의 태그 확인 
# 3) 해당 사이트에서 저자의 태그 확인
# 4) 책제목 & 저자의 정보를 크롤러를 통해서 찾아온다
# 5) 크롤러가 찾아온 정보를 변수생성 후 저장한다
# 6) 해당 변수를 출력한다
# 7)

# 8) 찾아온 결과값을 출력한다

# %% [markdown]
# - 200 : 클라이언트 요청에 서버가 문제없이 통신했다
# - 300 : 클라이언트 요청에 서버가 통신을 했으나, 다른곳으로 우회
# - 400 : 클라이언트 요청이 잘못된 경우, 서버에서 정상적으로 응답 x -> 404
# - 500 : 클라이언트 요청은 문제가 없으나, 서버에서 응답을 정상적으로 x

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.yes24.com/product/category/steadyseller?pageNumber=1&pageSize=24&categoryNumber=001001025007"

header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=header)
response.encoding = "utf-8" # 미국 -> 영어 // 일본, 중국, 한국
soup = BeautifulSoup(response. text, "html.parser")

books = soup.select("div.item_info")

#for book in books [5:11] :
#    title_tag = book.select_one("a.gd_name")
#    author_tag = book.select_one("span.authPub.info_auth")
#    print(title_tag.text.strip(), author_tag.text.strip())

for i, book in enumerate(books [5:10], 1) :
    title_tag = book.select_one("a.gd_name")
    author_tag = book.select_one("span.authPub.info_auth")
    print(f"{i}. {title_tag.text.strip()} - {author_tag.text.strip()}")

#title_tag = soup.select("a.gd_name")
#author_tag = soup.select("span.authPub.info_auth")

# print(title_tag) # 문자열에서만 사용가능!
# print(type(title_tag))
# print(dir(title_tag))

#for title in title_tag :
#    print(title.text)

#for author in author_tag :
#    print(author.text.strip()) # 엔터를 치는순간 => ＼n : escape sequence : n -> 일반적인 스펠링 문자, 개행처리 = 행바꿈
# Out:
# 1. 부의 추월차선 (10주년 스페셜 에디션) - 엠제이 드마코 저/신소영 역
# 2. 달러는 왜 비트코인을 싫어하는가 - 사이페딘 아모스 저/위대선 역
# 3. 경제기사 궁금증 300문 300답 - 곽해선 저
# 4. 트럼프 2.0 시대 - 박종훈 저
# 5. 시대예보: 호명사회 - 송길영 저
